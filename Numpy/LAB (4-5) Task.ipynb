# %% [markdown]
# # Machine Learning Lab (4-5) Tasks
#
#
# # LAB TASK Instructions
#
# - Attempt all questions.
# - Write clean and properly commented code.
# - Use NumPy functions wherever possible.
# - Include outputs of all questions.
# - Submit before the deadline.
# - Save the notebook with your roll number.
#
# ---
#
# # Import Required Libraries
#
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
# ```
#
# ---
#
# # LAB 4 — Tasks
#
# # Task 1 — Creating Arrays
#
# ## Question 1.1
# Create a 1D NumPy array containing numbers from 1 to 20.
#
# ```python
#
# ```
#
# ---
#
# ## Question 1.2
# Create an array of numbers from 1–64.
#
# Perform the following:
#
# Convert it into:
#    - `(8,8)`
#    - `(4,4,4)`
#    - `(2,2,4,4)`
#
# ---
#
# ## Question 1.3
# Create:
# - An array of zeros of shape `(5,5)`
# - An array of ones of shape `(3,4)`
# - An identity matrix of size `4×4`
#
# ```python
#
# ```
#
# ---
#
# # Task 2 — Array Attributes
#
# Given the following array:
#
# ```python
# arr = np.arange(60).reshape(3,4,5)
# ```
#
# ## Question 2.1
# Find:
# - Number of dimensions
# - Shape
# - Size
# - Datatype
#
# ```python
#
# ```
#
# ---
#
# ## Question 2.2
# Convert datatype into:
# - float32
# - int64
#
# ```python
#
# ```
#
# ---
#
# # Task 3 — Indexing and Slicing
#
# Given:
#
# ```python
# a = np.arange(1,26).reshape(5,5)
# ```
#
# ## Question 3.1
# Print:
# - First row
# - Last row
# - First column
# - Last column
#
# ```python
#
# ```
#
# ---
#
# ## Question 3.2
# Extract:
# - Center element
# - Diagonal elements
# - Corner elements
#
# ```python
#
# ```
#
# ---
#
# ## Question 3.3
# Print:
# - Alternate rows
# - Alternate columns
# - First 3 rows and first 2 columns
#
# ```python
#
# ```
# ---
#
# # Task 4 — Boolean Indexing
#
# Given:
#
# ```python
# arr = np.arange(1,51)
# ```
#
# ## Question 4.1
# Extract:
# - Even numbers
# - Odd numbers
# - Numbers greater than 25
# - Numbers divisible by 3
#
# ```python
#
# ```
#
# ---
#
# ## Question 4.2
# Replace:
# - All even numbers with `-1`
# - All numbers greater than 40 with `0`
#
# ```python
#
# ```
#
# ---
#
# # Task 5 — Sorting and Searching
#
# Given:
#
# ```python
# arr = np.array([12,5,7,33,19,45,2,18,29])
# ```
#
# ## Question 5.1
# Sort array in:
# - Ascending order
# - Descending order
#
# ```python
#
# ```
#
# ---
#
# ## Question 5.2
# Find:
# - Maximum value
# - Minimum value
# - Index of maximum value
# - Index of minimum value
#
# ```python
#
# ```
#
# ---
# # LAB 5 — Tasks
# # Task 6 — Broadcasting
#
# ## Question 6.1
#
# Create:
#
# ```python
# a = np.arange(12).reshape(3,4)
# b = np.array([10,20,30,40])
# ```
#
# Perform:
# - Addition
# - Multiplication
# - Subtraction
#
# ```python
#
# ```
#
# ---
#
# ## Question 6.2
#
# Create:
#
# ```python
# a = np.arange(12).reshape(3,4)
# b = np.arange(3)
# ```
#
# Try adding both arrays.
#
# - What error occurs?
# - Explain broadcasting rules.
#
# ```python
#
# ```
#
# ---
#
# # Task 7 — Stacking and Splitting
#
# ## Question 7.1
#
# Create:
#
# ```python
# a = np.arange(16).reshape(4,4)
# b = np.arange(16,32).reshape(4,4)
# ```
#
# Perform:
# - Horizontal stacking
# - Vertical stacking
#
# ```python
#
# ```
#
# ---
#
# ## Question 7.2
# Split arrays using:
# - `hsplit()`
# - `vsplit()`
#
# ```python
#
# ```
#
# ---
#
# # Task 8 — Statistical Functions
#
# ## Question 8.1
#
# Generate random marks for 100 students between 0–100.
#
# ```python
#
# ```
#
# ---
#
# ## Question 8.2
# Find:
# - Mean
# - Median
# - Standard deviation
# - Variance
# - Minimum marks
# - Maximum marks
#
# ```python
#
# ```
#
# ---
#
# ## Question 8.3
# Count:
# - Students above 50
# - Students below 40
#
# ```python
#
# ```
#
# ---
#
# # Task 9 — Checkerboard Pattern
#
# Create an `8×8` checkerboard matrix using NumPy.
#
# ```python
#
# ```
#
# ---
# # Task 10 — Mini Grade System
#
# Generate marks for 200 students and assign grades:
#
# | Marks Range | Grade |
# |-------------|------|
# | 80+ | A |
# | 70–79 | B |
# | 60–69 | C |
# | 50–59 | D |
# | Below 50 | F |
#
# ```python
#
# ```
#
# ---
