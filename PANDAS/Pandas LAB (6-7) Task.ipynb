# %% [markdown]
# # Lab (6–7) Tasks: Pandas Data Analysis using Sales Dataset
#
# ## Objective
#
# The objective of this lab assignment is to practice:
#
# - Working with Pandas DataFrames
# - Data analysis and manipulation
# - Filtering and sorting data
# - Feature engineering
# - GroupBy operations
# - Business data analysis
# - Data visualization using Matplotlib
#
# ---
#
# # Dataset: Store Sales Dataset
# Load a provided sale_dataset that consists of 12 rows and 6 columns
#
# ---
#
# # LAB Tasks
#
# ## Part A — Dataset Understanding
#
# ### Task 1
# Display:
# - First 5 rows
# - Last 3 rows
# - Shape of dataset
#
# ### Task 2
# Display:
# - Column names
# - Data types
# - Dataset information
#
# ### Task 3
# Generate statistical summary of numerical columns.
#
# ---
#
# ## Part B — Feature Engineering
#
# ### Task 4
# Create a new column named `Total_Sale`
#
# Formula:
#
# ```python
# Price * Quantity
# ```
#
# ### Task 5
# Create another column named `Discount`
#
# Condition:
# - If `Total_Sale > 100000` → 5% discount
# - Otherwise → 2% discount
#
# ### Task 6
# Create final amount column named `Final_Amount`
#
# Formula:
#
# ```python
# Final_Amount = Total_Sale - Discount
# ```
#
# ---
#
# ## Part C — Filtering and Selection
#
# ### Task 7
# Display all orders where:
# - Quantity greater than 2
#
# ### Task 8
# Display all Electronics products.
#
# ### Task 9
# Display all orders from Lahore city.
#
# ### Task 10
# Display products where:
# - `Final_Amount > 50000`
#
# ---
#
# ## Part D — Sorting and GroupBy Analysis
#
# ### Task 11
# Sort dataset by `Final_Amount` in descending order.
#
# ### Task 12
# Display top 3 highest sales records.
#
# ### Task 13
# Find total sales city-wise.
#
# ### Task 14
# Find average quantity product-wise.
#
# ### Task 15
# Find maximum `Final_Amount` category-wise.
#
# ---
#
# ## Part E — Data Visualization
#
# ### Task 16
# Create a bar chart of:
# - Product vs Total Sales
#
# Hint:
#
# ```python
# import matplotlib.pyplot as plt
# ```
#
# ### Task 17
# Create a pie chart of:
# - City-wise sales distribution
#
# ---
#
# ### Task 18
# Save final dataset into:
#
# ```python
# sales_report.csv
# ```
#
# ---
