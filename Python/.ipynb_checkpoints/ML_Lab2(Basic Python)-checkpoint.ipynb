# %% [markdown]
# # *Print Statement*

# %%
print("Welcome in ML Lab")
# Out:
# Welcome in ML Lab

# %% [markdown]
# # **Comments**

# %% [markdown]
# Comments are used to write something which the programmer does not want to
# execute. This can be used to mark author name, date etc
#
# **Types of comments**
#
#
# 1. Single line
# 2. Multi line

# %%
#Single line comment
"""
Author: Shaista Zulfiqar
Date: 7 March 2026
"""
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# # **Variables**

# %% [markdown]
# **What is a variable?**
#
# A variable is like a container or a box where we store information.

# %% [markdown]
# **Rules for variables**
#
#
#
# *   No spaces
# *   Cannot start with a number
#
# *   Use meaningful names
# *   Python is case-sensitive (Name vs name are different)

# %%
#Code
name="Shaista"
print(name)
age=26
print(age)
# Out:
# Shaista
# 26

# %% [markdown]
# # **Data Types**

# %% [markdown]
# **Integers (int)**
#
# Whole numbers without decimals.
# Examples: 10, -5, 1000

# %% [markdown]
# **Floating Point Numbers (float)**
#
# Numbers with decimals.
# Examples: 2.5, 0.1, -3.14

# %% [markdown]
# **Strings (str)**
#
# Text written inside quotes.
# Examples: "Shaista", 'Python'

# %% [markdown]
# **Booleans (bool)**
#
# Either True or False.
# Used in logic and decisions.

# %%
#Code
age = 25          # int
price = 2.5       # float
name = "Shaista"  # string
is_student = True # boolean

print(age)
print(price)
print(name)
print(is_student)
# Out:
# 25
# 2.5
# Shaista
# True

# %%
marks=78
print(type(marks)) #type() is used to check the variable type
# Out:
# <class 'int'>

# %% [markdown]
# # **Type Casting**

# %% [markdown]
# Type casting means converting one data type into another.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Code
print(marks)
print(type(marks))   #int datatype
marks=(float(marks)) #type-casting
print(type(marks))
# Out:
# 78
# <class 'int'>
# <class 'float'>

# %% [markdown]
# # **Basic Operators**

# %% [markdown]
# 1. **Arithmetic operators:** +, -, *, / etc.
#
# 2. **Assignment operators:** =, +=, -= etc.
#
# 3. **Comparison operators:** ==, >, >=, <, != etc.
#
# 4. **Logical operators:** and, or, not.

# %%
#Arithmetic operators
a = 11
b = 3
print(a + b)  
print(a - b)  
print(a * b)  
print(a / b)  # normal division (decimal result)
print(a // b)  # floor division (integer result (no decimal)
print(a%b)
# Out:
# 14
# 8
# 33
# 3.6666666666666665
# 3
# 2

# %%
#Assignment operators
x = 5
print("x =", x)

# Add and assign
x += 5   # x = x + 5
print("x after += 5:", x)

# Subtract and assign
x -= 3   # x = x - 3
print("x after -= 3:", x)

# Multiply and assign
x *= 2   # x = x * 2
print("x after *= 2:", x)
# Out:
# x = 5
# x after += 5: 10
# x after -= 3: 7
# x after *= 2: 14

# %%
#Comparison operators
a = 10
b = 5

print("a == b:", a == b)   # equal
print("a != b:", a != b)   # not equal
print("a > b:", a > b)     # greater than
print("a < b:", a < b)     # less than
print("a >= b:", a >= b)   # greater or equal
print("a <= b:", a <= b)   # less or equal
# Out:
# a == b: False
# a != b: True
# a > b: True
# a < b: False
# a >= b: True
# a <= b: False

# %%
#Logical operators
x = True
y = False

print("x and y:", x and y)   # both True
print("x or y:", x or y)     # at least one True
print("not x:", not x)       # reverses the value
# Out:
# x and y: False
# x or y: True
# not x: False

# %% [markdown]
# # **Input Function**

# %%
#code
marks=input("Enter marks")
print(type(marks))
# Out:
# Enter marks 67
# <class 'str'>

# %% [markdown]
# # **String**
#
# String is a data type in python.
#
# String is a sequence of characters enclosed in quotes.

# %% [markdown]
# **String Slicing**
#
# A string in python can be sliced for getting a part of the strings.

# %%
text1 = "Hello"
text2 = 'Python'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
name = "ShaistaZulfiqar"
print(name[0:6])   # Shaista
print(name[7:14])  # Zulfiqar
print(name[:7])    # Shaista
print(name[7:])    # Zulfiqar
# Out:
# Shaist
# Zulfiqa
# Shaista
# Zulfiqar

# %% [markdown]
# **String Functions**

# %% [markdown]
# **len()** : counts characters
#
# **capitalize()**:	 Converts the first character to upper case
#
# **count()**:	Returns the number of times a specified value occurs in a string
#
# **endswith()**:	Returns true if the string ends with the specified value
#
# **startswith()**:	Returns true if the string starts with the specified value
#
# **isalnum()**: Returns True if all characters in the string are alphanumeric
#
# **lower()**:	Converts a string into lower case
#
# **upper()**: Converts a string into upper case

# %%
#len() : counts characters
word = "python programming"
print(len(word))
# Out:
# 18

# %%
#capitalize(): Converts the first character to upper case
sentence = "shaista"
print(sentence.capitalize())
# Out:
# Shaista

# %%
#count(): Returns the number of times a specified value occurs in a string
word="Sana"
print(word.count("a"))
# Out:
# 2

# %%
#endswith(): Returns true if the string ends with the specified value
filename = "data.csv"
print(filename.endswith(".csv"))
# Out:
# True

# %%
#startswith(): Returns true if the string starts with the specified value
filename = "data.csv"
print(filename.startswith("data"))
# Out:
# True

# %%
#Returns True if all characters in the string are alphanumeric
s1 = "Python3"
print(s1.isalnum())   # True
# Out:
# True

# %%
#lower(): Converts a string into lower case
name = "Shaista Zulfiqar"
print(name.lower())
# Out:
# shaista zulfiqar

# %%
#upper(): Converts a string into upper case
language = "python"
print(language.upper())
# Out:
# PYTHON

# %% [markdown]
# # **f-strings Formatting**
#
# f-strings allow combining text and variables easily.

# %%
a = 10
b = 5

print(f"The sum of {a} and {b} is {a+b}.")
# Out:
# The sum of 10 and 5 is 15.

# %%
num = 5/2
print(f"{num:.1f}")  # 2.5
print(f"{num:.2f}")  # 2.50
print(f"{num:.3f}")  # 2.500
# Out:
# 2.5
# 2.50
# 2.500

# %% [markdown]
# ## **Challenges For Students**
# 1. Write a Python program that creates the following variables:
#    * name
#    * age
#    * cgpa
#    * is_student
#
#    Print each variable and its data type using type().
# 2. Given the string: **text = "ArtificialIntelligence"** Write a program to print:
#
#    * Artificial
#
#    * Intelligence
#
#    * First 5 characters
#
#    * Last 5 characters
#
# 3. Write a Python program that:
#
#    * Takes a word from the user.
#
#    * Count how many times the letter "e" appears.
#
# 4. Write a Python program that:
#
#    * Takes three numbers from the user.
#
#    * Calculate the average.
#
#    * Print the result with 2 decimal places using f-string.
#
# 5. Write a Python program that takes a sentence from the user and print:
#
#    * Length of the sentence
#
#    * Sentence in uppercase
#
#    * Sentence in lowercase
#
#    * First letter capitalized
